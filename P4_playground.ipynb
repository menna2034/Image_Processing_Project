# %%
import math
import numpy as np
import cv2

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from calibration import *
from laneFinder import LaneFinder
from thresholder import Thresholder
from pipeline import PipeLine
from moviepy.editor import VideoFileClip


# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ### Compute the camera calibration matrix and distortion coefficients given a set of chessboard images.

# %%
# ------------------------------------
plt.rcParams['figure.figsize'] = (20, 15)


ret, mtx, dist = calDistortMatrix(ifPlot=True)

# %% [markdown]
# ### Apply the distortion correction to one of the calibration image:

# %%
# fn = 'test_images/straight_lines1.jpg'
fn = 'test_images/test3.jpg'
img = cv2.imread(fn)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_corrected = cv2.undistort(img, mtx, dist, None, mtx)

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(img_corrected)
ax2.set_title('Undistorted Image', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Undistorted Image')

# %% [markdown]
# ### Use color transforms, gradients, etc., to create a thresholded binary image
# Define all kinds of masking functions first.

# %% [markdown]
# Test the masking over testing images

# %%
# ------------------------------------
imgTest = img_corrected
thObj = Thresholder()

sobelx, sobely = thObj.get_gradient(imgTest)

gradmagMask = thObj.mag_thresh(sobelx, sobely)
graddirMask = thObj.dir_thresh(sobelx, sobely)
roiMask = thObj.roi_thresh(imgTest)
colorMask = thObj.color_thresh(imgTest)
combinedMask = thObj.threshold(imgTest)

# Display
f, axhandles = plt.subplots(2, 3, figsize=(20,10))

axhandles[0, 0].imshow(gradmagMask*255, cmap='gray')
axhandles[0, 0].set_title('Magnitude of Gradient Mask')
axhandles[0, 1].imshow(graddirMask*255, cmap='gray')
axhandles[0, 1].set_title('Direction of Gradient Mask')
axhandles[0, 2].imshow(roiMask*255, cmap='gray')
axhandles[0, 2].set_title('Region of Interest Mask')
    
axhandles[1, 0].imshow(colorMask, cmap='gray')
axhandles[1, 0].set_title('Yellow and White Color Mask')
axhandles[1, 1].imshow(imgTest)
axhandles[1, 1].set_title('Original Image')
axhandles[1, 2].imshow(combinedMask, cmap='gray')
axhandles[1, 2].set_title('Final Combined Mask')

plt.show()

# %% [markdown]
# ### Apply a perspective transform to rectify binary image ("birds-eye view").

# %%
# %autoreload 2

# define 4 points over a rectangular region within the lane in both the original view and the target (bird) view
M, M_inv = computePerspective(ifPlot=True)

# %%
# get mask and the bird-view of it
mask_orig = combinedMask
mask_bird = cv2.warpPerspective(np.float64(mask_orig), M, (mask_orig.shape[1], mask_orig.shape[0]), flags=cv2.INTER_LINEAR)

# Display
f, axhandles = plt.subplots(1,2, figsize=(20,10))

axhandles[0].imshow(mask_orig, cmap = 'gray')
axhandles[0].set_title('Original Combined Mask')

axhandles[1].imshow(mask_bird, cmap = 'gray')
axhandles[1].set_title(' Bird-view Combined Mask')
# Out:
# Text(0.5, 1.0, ' Bird-view Combined Mask')

# %% [markdown]
# ### Detect lane pixels and fit to find the lane boundary.

# %%
# %autoreload 2

plt.rcParams['figure.figsize'] = (15, 5)

# m = np.copy(mask_bird)
laneFinderObj = LaneFinder(M, M_inv)
outimg = laneFinderObj.run(imgTest, mask_bird)

# Display
proj = laneFinderObj.init_proj
halfLen = int(len(proj)/2)
rng1 = range(halfLen)
rng2 = range(halfLen, 2*halfLen)

plt.subplot(1,2,1)
plt.plot(rng1, proj[rng1], 'r', rng2, proj[rng2], 'b')
plt.title('Initial projection of lower half mask')
plt.subplot(1,2,2)
plt.imshow(laneFinderObj.mask_laneAndWindow)
plt.show()
# Out:
# Initial Lane Centers: left = 393, right = 870
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Determine the curvature of the lane and vehicle position with respect to center.

# %%
car_position = laneFinderObj.c_shift_cm
print("Car location {:.3f} cm off center. ".format(car_position))
# Out:
# Car location -19.485 cm off center.

# %% [markdown]
# ### Warp the detected lane boundaries back onto the original image. Output visual display of the lane boundaries and numerical estimation of lane curvature and vehicle position.

# %%
output_origView = laneFinderObj.final

# Display
plt.rcParams['figure.figsize'] = (15, 15)

plt.imshow(output_origView)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Re-run the whole pipeline over a single image

# %%
# %autoreload 2

img = img_corrected

p = PipeLine()
res = p.run_Pipeline(img)

# Display
plt.rcParams['figure.figsize'] = (15, 15)

plt.imshow(res)
plt.show()
# Out:
# Pipeline Initialization: Calculating lens distortion ...
# Pipeline Initialization: Calculating bird view transform matrix ...
# Pipeline Initialization: Initializing LaneFinder instance ...
# Initial Lane Centers: left = 393, right = 870
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
## Run the pipeline over the entire video

# %%
# %autoreload 2

input_fn = 'videos/project_video.mp4'
tmp = input_fn.split('.')
tmp[0] += '_output'
output_fn = '.'.join(tmp)

p = PipeLine()

video_input1 = VideoFileClip(input_fn)#.subclip(35, 42)
processed_video = video_input1.fl_image(p.run_Pipeline)

# %time processed_video.write_videofile(output_fn, audio=False)
# Out:
# Pipeline Initialization: Calculating lens distortion ...
# Pipeline Initialization: Calculating bird view transform matrix ...
# Pipeline Initialization: Initializing LaneFinder instance ...
# Initial Lane Centers: left = 394, right = 884
# Moviepy - Building video videos/project_video_output.mp4.
# Moviepy - Writing video videos/project_video_output.mp4
# t:  82%|█████████████████████████████████████████████████████            | 1028/1260 [06:15<00:55,  4.18it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-171> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     133              for (k,v) in k.items()}
#     134
# --> 135     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-170> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# ~\anaconda3\lib\site-packages\moviepy\video\VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     298                                        logger=logger)
#     299
# --> 300         ffmpeg_write_video(self, filename, fps, codec,
#     301                            bitrate=bitrate,
#     302                            preset=preset,
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     218         nframes = int(clip.duration*fps)
#     219
# --> 220         for t,frame in clip.iter_frames(logger=logger, with_times=True,
#     221                                         fps=fps, dtype="uint8"):
#     222             if withmask:
#
# ~\anaconda3\lib\site-packages\moviepy\Clip.py in iter_frames(self, fps, with_times, logger, dtype)
#     470         logger = proglog.default_bar_logger(logger)
#     471         for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472             frame = self.get_frame(t)
#     473             if (dtype is not None) and (frame.dtype != dtype):
#     474                 frame = frame.astype(dtype)
#
# <decorator-gen-128> in get_frame(self, t)
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# ~\anaconda3\lib\site-packages\moviepy\Clip.py in get_frame(self, t)
#      91                 return frame
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#      95     def fl(self, fun, apply_to=None, keep_duration=True):
#
# ~\anaconda3\lib\site-packages\moviepy\Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# ~\anaconda3\lib\site-packages\moviepy\video\VideoClip.py in <lambda>(gf, t)
#     488         """
#     489         apply_to = apply_to or []
# --> 490         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     491
#     492     # --------------------------------------------------------------
#
# C:\image_project_4\CarND-Advanced-Lane-Lines-master\pipeline.py in run_Pipeline(self, img)
#      45         # Generate mask for lane edges and transform to bird view
#      46         thObj = Thresholder()
# ---> 47         mask = thObj.threshold(img) #combinedMask
#      48         mask_bird = cv2.warpPerspective(np.float64(mask), self.M, (mask.shape[1], mask.shape[0]), flags=cv2.INTER_LINEAR)
#      49         # combinedMask , orig_img, bird_img, mask_bird, img_with_lanes = my_fun(img)
#
# C:\image_project_4\CarND-Advanced-Lane-Lines-master\thresholder.py in threshold(self, img)
#      67
#      68     def threshold(self, img):
# ---> 69         sobelx, sobely = self.get_gradient(img)
#      70
#      71         direc = self.dir_thresh(sobelx, sobely)
#
# C:\image_project_4\CarND-Advanced-Lane-Lines-master\thresholder.py in get_gradient(self, img)
#      60
#      61     def get_gradient(self, img):
# ---> 62         sobelx = cv2.Sobel(img[:, :, 2], cv2.CV_64F, 1, 0, ksize=self.sobel_kernel)
#      63         sobely = cv2.Sobel(img[:, :, 2], cv2.CV_64F, 0, 1, ksize=self.sobel_kernel)
#      64
#
# KeyboardInterrupt:
